# %%
from particles_mod.Icosphere import *
import hydrodynamic_int.hessian as hess
import numpy as np
import pyvista as pv
import matplotlib.pyplot as plt
np.set_printoptions(precision=3)
pv.set_jupyter_backend('html')
# Out:
#    ██╗   ██╗██╗     ███╗   ███╗██████╗
#    ██║   ██║██║     ████╗ ████║██╔══██╗
#    ██║   ██║██║     ██╔████╔██║██████╔╝
#    ╚██╗ ██╔╝██║     ██║╚██╔╝██║██╔═══╝
#     ╚████╔╝ ███████╗██║ ╚═╝ ██║██║
#      ╚═══╝  ╚══════╝╚═╝     ╚═╝╚═╝
#     VIRTUAL   LAB    MODELING  PLATFORM
# 03/06/2025 09:52:10 - VLMP - INFO - Starting VLMP...
# 03/06/2025 09:52:10 - VLMP - ERROR - No module named 'orthopoly' (__init__.py:187)
# 03/06/2025 09:52:10 - VLMP - ERROR - [Model] Error importing model type component CORONAVIRUS (__init__.py:188)
# 03/06/2025 09:52:10 - VLMP - ERROR - No module named 'Bio' (__init__.py:187)
# 03/06/2025 09:52:10 - VLMP - ERROR - [Model] Error importing model type component ENM (__init__.py:188)
# 03/06/2025 09:52:10 - VLMP - ERROR - No module named 'pyquaternion' (__init__.py:187)
# 03/06/2025 09:52:10 - VLMP - ERROR - [Model] Error importing model type component HELIX (__init__.py:188)
# 03/06/2025 09:52:10 - VLMP - ERROR - No module named 'Bio' (__init__.py:187)
# 03/06/2025 09:52:10 - VLMP - ERROR - [Model] Error importing model type component IDP (__init__.py:188)
# 03/06/2025 09:52:10 - VLMP - ERROR - No module named 'Bio' (__init__.py:187)
# 03/06/2025 09:52:10 - VLMP - ERROR - [Model] Error importing model type component KB (__init__.py:188)
# 03/06/2025 09:52:10 - VLMP - ERROR - No module named 'Bio' (__init__.py:187)
# 03/06/2025 09:52:10 - VLMP - ERROR - [Model] Error importing model type component PROTEIN_IDP_PROTEIN (__init__.py:188)
# 03/06/2025 09:52:10 - VLMP - ERROR - No module named 'Bio' (__init__.py:187)
# 03/06/2025 09:52:10 - VLMP - ERROR - [Model] Error importing model type component SBCG (__init__.py:188)
# 03/06/2025 09:52:10 - VLMP - ERROR - No module named 'Bio' (__init__.py:187)
# 03/06/2025 09:52:10 - VLMP - ERROR - [Model] Error importing model type component SOP (__init__.py:188)
# 03/06/2025 09:52:10 - VLMP - ERROR - No module named 'pyquaternion' (__init__.py:141)
# 03/06/2025 09:52:10 - VLMP - ERROR - [ModelOperation] Error importing model operation type component distributeRandomly (__init__.py:142)

# %%
radius = 10.0
density = 2.0
Kpair = 20
Kdi = 0.5

positions, bonds = construct_structure(radius=radius, density=density, Kpair=Kpair, Kdi=Kdi)
# Out:
# 03/06/2025 09:52:10 - VLMP - INFO - [VLMP] Starting VLMP
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Processing "system" component ({'type': 'simulationName', 'parameters': {'simulationName': 'Icosphere'}}), type "simulationName" (VLMP.py:194)
# 03/06/2025 09:52:10 - VLMP - WARNING - [VLMP] (system) Component name not specified, using "simulationName".
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (system) Component name "simulationName". (VLMP.py:200)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (system) Component parameters "{'simulationName': 'Icosphere'}" (VLMP.py:207)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Processing "system" component ({'type': 'simulationName', 'parameters': {'simulationName': 'Icosphere'}}), type "simulationName" (VLMP.py:194)
# 03/06/2025 09:52:10 - VLMP - WARNING - [VLMP] (system) Component name not specified, using "simulationName".
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (system) Component name "simulationName". (VLMP.py:200)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (system) Component parameters "{'simulationName': 'Icosphere'}" (VLMP.py:207)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Adding system "simulationName" (VLMP.py:251)
# 03/06/2025 09:52:10 - VLMP - INFO - [System] (simulationName) Using system simulationName
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Processing "units" component ({'type': 'none'}), type "none" (VLMP.py:194)
# 03/06/2025 09:52:10 - VLMP - WARNING - [VLMP] (units) Component name not specified, using "none".
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (units) Component name "none". (VLMP.py:200)
# 03/06/2025 09:52:10 - VLMP - WARNING - [VLMP] (units) Component parameters not specified, creating empty dictionary
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (units) Component parameters "{}" (VLMP.py:207)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Adding units "none" (VLMP.py:251)
# 03/06/2025 09:52:10 - VLMP - INFO - [Units] (none) Using units none
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Processing "types" component ({'type': 'basic'}), type "basic" (VLMP.py:194)
# 03/06/2025 09:52:10 - VLMP - WARNING - [VLMP] (types) Component name not specified, using "basic".
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (types) Component name "basic". (VLMP.py:200)
# 03/06/2025 09:52:10 - VLMP - WARNING - [VLMP] (types) Component parameters not specified, creating empty dictionary
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (types) Component parameters "{}" (VLMP.py:207)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Adding types "basic" (VLMP.py:251)
# 03/06/2025 09:52:10 - VLMP - INFO - [Types] (basic) Using types basic
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Processing "ensemble" component ({'type': 'NVT', 'parameters': {'box': [100.0, 100.0, 100.0], 'temperature': 0.0}}), type "NVT" (VLMP.py:194)
# 03/06/2025 09:52:10 - VLMP - WARNING - [VLMP] (ensemble) Component name not specified, using "NVT".
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (ensemble) Component name "NVT". (VLMP.py:200)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (ensemble) Component parameters "{'box': [100.0, 100.0, 100.0], 'temperature': 0.0}" (VLMP.py:207)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Adding ensemble "NVT" (VLMP.py:251)
# 03/06/2025 09:52:10 - VLMP - INFO - [Ensemble] (NVT) Using ensemble NVT
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Processing "models" component ({'type': 'ICOSPHERE', 'parameters': {'resolution': 16, 'radius': 10.0, 'particleName': 'S', 'particleRadius': 0.5, 'Kb': 20, 'Kd': 0.5, 'steric': False}}), type "ICOSPHERE" (VLMP.py:194)
# 03/06/2025 09:52:10 - VLMP - WARNING - [VLMP] (models) Component name not specified, using "ICOSPHERE".
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (models) Component name "ICOSPHERE". (VLMP.py:200)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] (models) Component parameters "{'resolution': 16, 'radius': 10.0, 'particleName': 'S', 'particleRadius': 0.5, 'Kb': 20, 'Kd': 0.5, 'steric': False}" (VLMP.py:207)
# 03/06/2025 09:52:10 - VLMP - DEBUG - [VLMP] Adding models "ICOSPHERE" (VLMP.py:251)
# 03/06/2025 09:52:10 - VLMP - INFO - [Model] (ICOSPHERE) Using model ICOSPHERE
# 03/06/2025 09:52:10 - VLMP - DEBUG - [Types] (basic) Adding type S for types basic. Declaration: {'name': 'S', 'mass': 1.0, 'radius': 0.5, 'charge': 0.0} (__init__.py:147)
# 03/06/2025 09:52:10 - VLMP - WARNING - [ICOSPHERE] Error loading bonds from model data
# 03/06/2025 09:52:11 - VLMP - WARNING - [ICOSPHERE] Error loading dihedrals from model data
# 03/06/2025 09:52:34 - VLMP - WARNING - [VLMP] (modelOperations) Section not found, skipping
# 03/06/2025 09:52:34 - VLMP - WARNING - [VLMP] (modelExtensions) Section not found, skipping
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Processing "integrators" component ({'type': 'BBK', 'parameters': {'timeStep': 0.0, 'frictionConstant': 0.0, 'integrationSteps': 1}}), type "BBK" (VLMP.py:194)
# 03/06/2025 09:52:34 - VLMP - WARNING - [VLMP] (integrators) Component name not specified, using "BBK".
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] (integrators) Component name "BBK". (VLMP.py:200)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] (integrators) Component parameters "{'timeStep': 0.0, 'frictionConstant': 0.0, 'integrationSteps': 1}" (VLMP.py:207)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Adding integrators "BBK" (VLMP.py:251)
# 03/06/2025 09:52:34 - VLMP - INFO - [Integrator] (BBK) Using integrator BBK
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Processing "simulationSteps" component ({'type': 'saveState', 'parameters': {'intervalStep': 0, 'outputFilePath': 'current_state', 'outputFormat': 'xyz'}}), type "saveState" (VLMP.py:194)
# 03/06/2025 09:52:34 - VLMP - WARNING - [VLMP] (simulationSteps) Component name not specified, using "saveState".
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] (simulationSteps) Component name "saveState". (VLMP.py:200)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] (simulationSteps) Component parameters "{'intervalStep': 0, 'outputFilePath': 'current_state', 'outputFormat': 'xyz'}" (VLMP.py:207)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Adding simulationSteps "saveState" (VLMP.py:251)
# 03/06/2025 09:52:34 - VLMP - DEBUG - Initializing idsHandler (__init__.py:24)
# 03/06/2025 09:52:34 - VLMP - DEBUG - Done initializing idsHandler (__init__.py:41)
# 03/06/2025 09:52:34 - VLMP - INFO - [SimulationStep] (saveState) Using simulation step saveState
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Merging components into a single simulation (VLMP.py:509)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Merging component "systems_simulationName" (VLMP.py:513)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Initializing simulation, ID: b60f24a8404f11f0a87fac1f6bd9c368 (simulation.py:72)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Simulation created (simulation.py:107)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Component "systems_simulationName" merged (VLMP.py:518)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Merging component "units_none" (VLMP.py:513)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Initializing simulation, ID: b60fcd2c404f11f0a87fac1f6bd9c368 (simulation.py:72)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Simulation created (simulation.py:107)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Appending "b60fcd2c404f11f0a87fac1f6bd9c368" to "b60f24a8404f11f0a87fac1f6bd9c368" with mode "modelId" (simulation.py:128)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Component "units_none" merged (VLMP.py:518)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Merging component "types_basic" (VLMP.py:513)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Initializing simulation, ID: b6109b76404f11f0a87fac1f6bd9c368 (simulation.py:72)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Simulation created (simulation.py:107)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Appending "b6109b76404f11f0a87fac1f6bd9c368" to "b60f24a8404f11f0a87fac1f6bd9c368" with mode "modelId" (simulation.py:128)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Component "types_basic" merged (VLMP.py:518)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Merging component "ensembles_NVT" (VLMP.py:513)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Initializing simulation, ID: b6117dd4404f11f0a87fac1f6bd9c368 (simulation.py:72)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Simulation created (simulation.py:107)
# 03/06/2025 09:52:34 - pyUAMMD - DEBUG - Appending "b6117dd4404f11f0a87fac1f6bd9c368" to "b60f24a8404f11f0a87fac1f6bd9c368" with mode "modelId" (simulation.py:128)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Component "ensembles_NVT" merged (VLMP.py:518)
# 03/06/2025 09:52:34 - VLMP - DEBUG - [VLMP] Merging component "models_ICOSPHERE" (VLMP.py:513)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Initializing simulation, ID: b629cb3c404f11f0a87fac1f6bd9c368 (simulation.py:72)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Simulation created (simulation.py:107)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Appending "b629cb3c404f11f0a87fac1f6bd9c368" to "b60f24a8404f11f0a87fac1f6bd9c368" with mode "modelId" (simulation.py:128)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Component "models_ICOSPHERE" merged (VLMP.py:518)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Merging component "integrators_BBK" (VLMP.py:513)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Initializing simulation, ID: b64527f6404f11f0a87fac1f6bd9c368 (simulation.py:72)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Simulation created (simulation.py:107)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Appending "b64527f6404f11f0a87fac1f6bd9c368" to "b60f24a8404f11f0a87fac1f6bd9c368" with mode "modelId" (simulation.py:128)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Component "integrators_BBK" merged (VLMP.py:518)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Merging component "simulationSteps_saveState" (VLMP.py:513)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Initializing simulation, ID: b64620d4404f11f0a87fac1f6bd9c368 (simulation.py:72)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Simulation created (simulation.py:107)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Appending "b64620d4404f11f0a87fac1f6bd9c368" to "b60f24a8404f11f0a87fac1f6bd9c368" with mode "modelId" (simulation.py:128)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Component "simulationSteps_saveState" merged (VLMP.py:518)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Distributing simulation pool using mode "size" (VLMP.py:549)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Distributing simulation pool using size (VLMP.py:588)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Simulation set 0 has 1 simulations (VLMP.py:141)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Setting up simulation (VLMP.py:634)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Writing to json... (simulation.py:207)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Writing with JFIO (simulation.py:213)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Aggregating simulations in simulation set 0 (VLMP.py:723)
# Merging simulations set: 100%|██████████| 1/1 [00:00<00:00,  6.78it/s]
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Writing to json... (simulation.py:207)
# 03/06/2025 09:52:35 - pyUAMMD - DEBUG - Writing with JFIO (simulation.py:213)
# 03/06/2025 09:52:35 - VLMP - DEBUG - [VLMP] Simulation set up finished (VLMP.py:745)
# dict_keys(['bonds', 'dihedrals'])

# %%
hessian_analytical = hess.obtainHessian(positions, bonds, create_sp=False, method='Analytical')
hessian = hess.obtainHessian(positions, bonds, create_sp=False, method='Numerical')
# Out:
# [WARNING] UAMMD-structured Python wrapper is not compatible with UAMMD-structured self restarting mechanism
# [MESSAGE] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# [MESSAGE] ╻ ╻┏━┓┏┳┓┏┳┓╺┳┓
# [MESSAGE] ┃ ┃┣━┫┃┃┃┃┃┃ ┃┃ Version: 2.5
# [MESSAGE] ┗━┛╹ ╹╹ ╹╹ ╹╺┻┛
# [MESSAGE] Compiled at: May 23 2025 13:23:39
# [MESSAGE] Compiled in double precision mode
# [MESSAGE] Computation started at Tue Jun  3 09:52:35 2025
#
# [MESSAGE] [System] CUDA initialized
# [MESSAGE] [System] Using device: NVIDIA GeForce RTX 3080 with id: 0
# [MESSAGE] [System] Compute capability of the device: 8.6
# [MESSAGE] ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━
# [MESSAGE] [ExtendedSystem] (system) Name: Hessian_Calculation
# [MESSAGE] [ExtendedSystem] (system) Seed: 1748937155972656552
# [MESSAGE] [GlobalDataBase] Fundamental not specified, using default fundamental, "Time"
# [WARNING] [Time] No timeStep specified, using 0.0 as default.
# [MESSAGE] [Basic] Loaded type A, mass: 1.000000, radius: 0.500000, charge: 0.000000
# [MESSAGE] [ParticleData] Created with 2562 particles.
# [MESSAGE] [StateLoader] Loading property "id".
# [MESSAGE] [StateLoader] Loading property "position".
# [MESSAGE] [Topology] Loading types into particle data.
# [MESSAGE] [ParticleGroup] Group All created with All selector
# [MESSAGE] [ParticleGroup] Group All contains 2562 particles.
# [MESSAGE] [GroupsListFromInputEntries] Added group "All" with 2562 particles.
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [Interactor] BondsInteractor: "bonds" created.
# [MESSAGE] [Interactor] Acting on group All
# [MESSAGE] [BondsInteractor] (bonds) Particles in the bond: id_i----id_j
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [Interactor] BondsInteractor: "dihedrals" created.
# [MESSAGE] [Interactor] Acting on group All
# [MESSAGE] [BondsInteractor] (dihedrals) Particles in the bond: id_i----id_j----id_k----id_l
# [MESSAGE] [Topology] Added interactor "bonds".
# [MESSAGE] [Topology] Added interactor "dihedrals".
# [MESSAGE] [Interactor] Scheduled created.
# [MESSAGE] [Interactor] Acting on group All
# [MESSAGE] [ParticleGroup] Group All created with All selector
# [MESSAGE] [ParticleGroup] Group All contains 2562 particles.
# [MESSAGE] [GroupsListFromInputEntries] Added group "All" with 2562 particles.
# [MESSAGE] [IntegratorManager] (integrator) Integrator 'bbk' will run for 1 steps with order 1.
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [Integrator] bbk created.
# [MESSAGE] [Integrator] Acting on group All
# [MESSAGE] [ExtendedSystem] (system) Creating cuda stream
# [MESSAGE] [IntegratorBase] (bbk) Time step: 0.000000
# [MESSAGE] [IntegratorBase] (bbk) Current step: 0
# [MESSAGE] [IntegratorBaseNVT] (bbk) Temperature: 0.000000
# [MESSAGE] [IntegratorBaseNVT] (bbk) kBT (kB 1.000000): 0.000000
# [MESSAGE] [BBK] Created BBK integrator "bbk"
# [MESSAGE] [BBK] (bbk) frictionConstant : 1.000000
# [MESSAGE] [IntegratorUtils] Loading friction constant (1.000000) to all particles.
# [MESSAGE] [BBK] (bbk) stopTransRotSteps : 0
# [MESSAGE] [BBK] (bbk) resetVelocities : 1
# [MESSAGE] [IntegratorManager] (integrator) Integrator 'bbk' loaded.
# [MESSAGE] [ParticleGroup] Group All created with All selector
# [MESSAGE] [ParticleGroup] Group All contains 2562 particles.
# [MESSAGE] [GroupsListFromInputEntries] Added group "All" with 2562 particles.
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [SimulationStep] (hessianMeasure) intervalStep: 1
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [SimulationStep] (info) intervalStep: 1
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [SimulationStep] (output) intervalStep: 1
# [MESSAGE] [WriteStep] (output) outputFilePath: /home/joan/hydrodynamic_int/test/results/output.txt
# [MESSAGE] [WriteStep] (output) outputFormat: sp
# [MESSAGE] [WriteStep] (output) pbc: 1
# [MESSAGE] [WriteStep] (output) append: 0
# [MESSAGE] [SimulationStepManager] (simulationStep) Simulation step 'hessianMeasure' loaded.
# [MESSAGE] [SimulationStepManager] (simulationStep) Simulation step 'info' loaded.
# [MESSAGE] [SimulationStepManager] (simulationStep) Simulation step 'output' loaded.
# [MESSAGE] [Simulation] Running simulation...
# [MESSAGE] [Simulation] Running integrator (bbk), 1 steps...
# [MESSAGE] [bbk] Adding Interactor Scheduled...
# [MESSAGE] [bbk] Adding updatable
# [MESSAGE] [InfoStep] (info) Total steps: 1
# [MESSAGE] [BBK] Performing initialization step
# [WARNING] [GenerateVelocity] Velocity overwritten!
# [MESSAGE] [Simulation] Mean FPS: 0.038354
# [MESSAGE] ━ �� ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━
# [MESSAGE] [ExtendedSystem] (system) Destroying cuda stream
# [MESSAGE] Computation finished at Tue Jun  3 09:53:02 2025
#
# [MESSAGE] Time elapsed since creation: 26.621284s
# [MESSAGE] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Hessian matrix obtained from /home/joan/hydrodynamic_int/test/results/hessian.txt
# [WARNING] UAMMD-structured Python wrapper is not compatible with UAMMD-structured self restarting mechanism
# [MESSAGE] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# [MESSAGE] ╻ ╻┏━┓┏┳┓┏┳┓╺┳┓
# [MESSAGE] ┃ ┃┣━┫┃┃┃┃┃┃ ┃┃ Version: 2.5
# [MESSAGE] ┗━┛╹ ╹╹ ╹╹ ╹╺┻┛
# [MESSAGE] Compiled at: May 23 2025 13:23:39
# [MESSAGE] Compiled in double precision mode
# [MESSAGE] Computation started at Tue Jun  3 09:53:09 2025
#
# [MESSAGE] [System] CUDA initialized
# [MESSAGE] [System] Using device: NVIDIA GeForce RTX 3080 with id: 0
# [MESSAGE] [System] Compute capability of the device: 8.6
# [MESSAGE] ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━
# [MESSAGE] [ExtendedSystem] (system) Name: Hessian_Calculation
# [MESSAGE] [ExtendedSystem] (system) Seed: 1748937189465228415
# [MESSAGE] [GlobalDataBase] Fundamental not specified, using default fundamental, "Time"
# [WARNING] [Time] No timeStep specified, using 0.0 as default.
# [MESSAGE] [Basic] Loaded type A, mass: 1.000000, radius: 0.500000, charge: 0.000000
# [MESSAGE] [ParticleData] Created with 2562 particles.
# [MESSAGE] [StateLoader] Loading property "id".
# [MESSAGE] [StateLoader] Loading property "position".
# [MESSAGE] [Topology] Loading types into particle data.
# [MESSAGE] [ParticleGroup] Group All created with All selector
# [MESSAGE] [ParticleGroup] Group All contains 2562 particles.
# [MESSAGE] [GroupsListFromInputEntries] Added group "All" with 2562 particles.
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [Interactor] BondsInteractor: "bonds" created.
# [MESSAGE] [Interactor] Acting on group All
# [MESSAGE] [BondsInteractor] (bonds) Particles in the bond: id_i----id_j
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [Interactor] BondsInteractor: "dihedrals" created.
# [MESSAGE] [Interactor] Acting on group All
# [MESSAGE] [BondsInteractor] (dihedrals) Particles in the bond: id_i----id_j----id_k----id_l
# [MESSAGE] [Topology] Added interactor "bonds".
# [MESSAGE] [Topology] Added interactor "dihedrals".
# [MESSAGE] [Interactor] Scheduled created.
# [MESSAGE] [Interactor] Acting on group All
# [MESSAGE] [ParticleGroup] Group All created with All selector
# [MESSAGE] [ParticleGroup] Group All contains 2562 particles.
# [MESSAGE] [GroupsListFromInputEntries] Added group "All" with 2562 particles.
# [MESSAGE] [IntegratorManager] (integrator) Integrator 'bbk' will run for 1 steps with order 1.
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [Integrator] bbk created.
# [MESSAGE] [Integrator] Acting on group All
# [MESSAGE] [ExtendedSystem] (system) Creating cuda stream
# [MESSAGE] [IntegratorBase] (bbk) Time step: 0.000000
# [MESSAGE] [IntegratorBase] (bbk) Current step: 0
# [MESSAGE] [IntegratorBaseNVT] (bbk) Temperature: 0.000000
# [MESSAGE] [IntegratorBaseNVT] (bbk) kBT (kB 1.000000): 0.000000
# [MESSAGE] [BBK] Created BBK integrator "bbk"
# [MESSAGE] [BBK] (bbk) frictionConstant : 1.000000
# [MESSAGE] [IntegratorUtils] Loading friction constant (1.000000) to all particles.
# [MESSAGE] [BBK] (bbk) stopTransRotSteps : 0
# [MESSAGE] [BBK] (bbk) resetVelocities : 1
# [MESSAGE] [IntegratorManager] (integrator) Integrator 'bbk' loaded.
# [MESSAGE] [ParticleGroup] Group All created with All selector
# [MESSAGE] [ParticleGroup] Group All contains 2562 particles.
# [MESSAGE] [GroupsListFromInputEntries] Added group "All" with 2562 particles.
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [SimulationStep] (hessianMeasure) intervalStep: 1
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [SimulationStep] (info) intervalStep: 1
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [SimulationStep] (output) intervalStep: 1
# [MESSAGE] [WriteStep] (output) outputFilePath: /home/joan/hydrodynamic_int/test/results/output.txt
# [MESSAGE] [WriteStep] (output) outputFormat: sp
# [MESSAGE] [WriteStep] (output) pbc: 1
# [MESSAGE] [WriteStep] (output) append: 0
# [MESSAGE] [SimulationStepManager] (simulationStep) Simulation step 'hessianMeasure' loaded.
# [MESSAGE] [SimulationStepManager] (simulationStep) Simulation step 'info' loaded.
# [MESSAGE] [SimulationStepManager] (simulationStep) Simulation step 'output' loaded.
# [MESSAGE] [Simulation] Running simulation...
# [MESSAGE] [Simulation] Running integrator (bbk), 1 steps...
# [MESSAGE] [bbk] Adding Interactor Scheduled...
# [MESSAGE] [bbk] Adding updatable
# [MESSAGE] [InfoStep] (info) Total steps: 1
# [MESSAGE] [BBK] Performing initialization step
# [WARNING] [GenerateVelocity] Velocity overwritten!
# [MESSAGE] [Simulation] Mean FPS: 0.029074
# [MESSAGE] ━ �� ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━
# [MESSAGE] [ExtendedSystem] (system) Destroying cuda stream
# [MESSAGE] Computation finished at Tue Jun  3 09:53:44 2025
#
# [MESSAGE] Time elapsed since creation: 34.689861s
# [MESSAGE] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Hessian matrix obtained from /home/joan/hydrodynamic_int/test/results/hessian.txt

# %%
symmetry = hessian - hessian.transpose(1,0,3,2)
symmetry_an = hessian_analytical - hessian_analytical.transpose(1,0,3,2)
symmetry = symmetry/np.mean(np.abs(hessian))
symmetry_an = symmetry_an/np.mean(np.abs(hessian_analytical))
plt.hist(symmetry.flatten(), bins=100, alpha=0.25, label='Numerical')
plt.hist(symmetry_an.flatten(), alpha=1, label='Analytical')
plt.title('Symmetry of Hessian Matrix')
plt.xlabel('Deviation / Max Absolute Value')
plt.ylabel('Frequency')
plt.yscale('log')
plt.legend()
plt.show()
symmetry_err = np.allclose(symmetry_an, 0.0, atol=1e-6)
print("Symmetry of Hessian matrix:", symmetry_err)
# Out:
# Symmetry of Hessian matrix: True

# %%
eigenvalues, eigenvectors, hessian_reshaped, eigenvectors_reshaped = hess.diagonalize_hessian(hessian)
eigenvalues_analytical, eigenvectors_analytical, hessian_reshaped_analytical, eigenvectors_reshaped_analytical = hess.diagonalize_hessian(hessian_analytical)

# %%
print("Number of eigenvalues: ", len(eigenvalues))
print("Eigenvectors shape: ", eigenvectors.shape)

print("Maximum eigenvalue: ", np.max(eigenvalues))
print("Minimum eigenvalue: ", np.min(eigenvalues))

orthogonality = eigenvectors_reshaped_analytical @ eigenvectors_reshaped_analytical.T - np.eye(eigenvectors_reshaped_analytical.shape[0])

print("Orthogonality error (Analytical): ", np.max(np.abs(orthogonality)))
# Out:
# Number of eigenvalues:  7686
# Eigenvectors shape:  (7686, 2562, 3)
# Maximum eigenvalue:  120.8552070053875
# Minimum eigenvalue:  -2.7177956589941288e-08
# Orthogonality error (Analytical):  1.1102230246251565e-15

# %%
absolute_tolerance = 5e-3
relative_tolerance = 5e-4

# use the tolerance to determine unique eigenvalues
unique_eigenvalues = [ev for i, ev in enumerate(eigenvalues_analytical) if i == 0 or np.abs(ev - eigenvalues_analytical[i-1]) > absolute_tolerance + relative_tolerance * np.abs(ev) ]

# group the mode_groups by their eigenvalues
mode_groups = []
for i, ev in enumerate(unique_eigenvalues):
    mode_groups.append(np.where(np.isclose(eigenvalues_analytical, ev, atol=absolute_tolerance, rtol=relative_tolerance))[0])

print("Number of unique eigenvalues: ", len(unique_eigenvalues)) 

plt.scatter(range(len(unique_eigenvalues)-1), np.array(unique_eigenvalues[1:]) - np.array(unique_eigenvalues[:-1]), marker='o', color='blue', label='Eigenvalue Differences')
plt.title('Eigenvalue Differences')
plt.xlabel('Index')
plt.ylabel('Eigenvalue Difference')
plt.yscale('log')
plt.show()
# Out:
# Number of unique eigenvalues:  1276

# %%
def plot_eigenvalues(ax, eigenvalues: np.ndarray, title : str =None):
    """
    Plot the eigenvalues of the Hessian matrix.
    :param eigenvalues: A numpy array containing the eigenvalues of the Hessian matrix.
    :param title: The title of the graph.
    """
    ax.plot(eigenvalues, 'o')
    ax.set_xlabel('Eigenvalue Index')
    ax.set_ylabel('Eigenvalue')
    ax.set_title('Eigenvalues of Hessian Matrix')
    ax.set_yscale('log')
    if title:
        plt.title(title)

fig, ax = plt.subplots(1, 1, figsize=(12, 6))
plot_eigenvalues(ax, unique_eigenvalues, title='Eigenvalues of Hessian Matrix (Analytical)')
plt.tight_layout()
plt.show()

# %%
def plot_mode(positions : list, eigenmode: np.ndarray):
    """
    Plot the eigenmode of the Hessian matrix.
    :param positions: A list of tuples containing the x, y and z coordinates of each particle.
    :param eigenvectors: A numpy array containing the eigenmode data in (nparticles, 3) format.
    :param mode: The index of the eigenmode to plot.
    """

    new_positions = np.array(positions) + np.array(eigenmode) * 100  # Scale the eigenmode for visualization

    mesh = pv.PolyData(new_positions)
    mesh = mesh.delaunay_3d()
    mesh['Eigenvector'] = eigenmode  # Add the eigenmode as a scalar field for coloring
    p = pv.Plotter()
    p.add_mesh(mesh, scalars='Eigenvector', show_scalar_bar=True, show_edges=False, cmap='coolwarm')
    p.add_arrows(np.array(positions), eigenmode / np.max(np.linalg.norm(eigenmode, axis=1))*2, color='blue', opacity=0.95
                 , name='Eigenvector Arrows')
    p.window_size = [300, 250]
    # add the coordinate triad bigger
    p.add_axes(interactive=True, line_width=5, labels_off=False, color='black')
    p.show()

modes = mode_groups[6]  

for mode in modes:
    plot_mode(positions, eigenvectors_analytical[mode,:,:])
    print(f"Eigenvalue {mode}: ", eigenvalues_analytical[mode])
# Out:
# 2025-06-03 09:55:02.157 ( 171.641s) [    7FAB5D94F5C0]      vtkDelaunay3D.cxx:513   WARN| vtkDelaunay3D (0x55b417157420): 2 degenerate triangles encountered, mesh quality suspect
# 2025-06-03 09:55:02.162 ( 171.646s) [    7FAB5D94F5C0]vtkXOpenGLRenderWindow.:1416  WARN| bad X server connection. DISPLAY=
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
# Eigenvalue 30:  0.11684627742672897
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
# Eigenvalue 31:  0.1189523222734056
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
# Eigenvalue 32:  0.11895232227341214
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
# Eigenvalue 33:  0.11895232227341493
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
# Eigenvalue 34:  0.11895232227341553
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
# Eigenvalue 35:  0.11895232227342202
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
# Eigenvalue 36:  0.11960597421904635
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
# Eigenvalue 37:  0.11960597421904837
# EmbeddableWidget(value='<iframe srcdoc="<!DOCTYPE html>\n<html>\n  <head>\n    <meta http-equiv=&quot;Content-…
# Eigenvalue 38:  0.11960597421905277
