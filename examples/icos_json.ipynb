# %%
import particles_mod.Icosphere as ico
import numpy as np
import pyinstrument as pin

# %%
! conda install -c conda-forge pyinstrument -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.1
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/joan/miniforge3/envs/hydint_env
#
#   added / updated specs:
#     - pyinstrument
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pyinstrument-5.0.3         |  py312h66e93f0_0         180 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         180 KB
#
# The following NEW packages will be INSTALLED:
#
#   pyinstrument       conda-forge/linux-64::pyinstrument-5.0.3-py312h66e93f0_0
#
# The following packages will be UPDATED:
#
# ...

# %%
num_particles = 4000
radius = 10
density = num_particles / (4 * np.pi * radius**2)

icosphere = ico.IcoSphere(radius=radius, density=density)
# Out:
# Creating icosphere with 1800 particles and frequency division 13
# Icosphere created with normalized positions and faces.
# Number of particles: 1692
# Generating VLMP data for the icosphere.
# 08/07/2025 10:54:12 - VLMP - INFO - [VLMP] Starting VLMP
# 08/07/2025 10:54:12 - VLMP - DEBUG - [VLMP] Processing "system" component ({'type': 'simulationName', 'parameters': {'simulationName': 'Icosphere'}}), type "simulationName" (VLMP.py:194)
# 08/07/2025 10:54:12 - VLMP - WARNING - [VLMP] (system) Component name not specified, using "simulationName".
# 08/07/2025 10:54:12 - VLMP - DEBUG - [VLMP] (system) Component name "simulationName". (VLMP.py:200)
# 08/07/2025 10:54:12 - VLMP - DEBUG - [VLMP] (system) Component parameters "{'simulationName': 'Icosphere'}" (VLMP.py:207)
# 08/07/2025 10:54:12 - VLMP - DEBUG - [VLMP] Processing "system" component ({'type': 'simulationName', 'parameters': {'simulationName': 'Icosphere'}}), type "simulationName" (VLMP.py:194)
# ...

# %%
modes = icosphere.obtain_modes()
# Out:
# Preliminary simulation structure created
# [WARNING] UAMMD-structured Python wrapper is not compatible with UAMMD-structured self restarting mechanism
# [MESSAGE] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# [MESSAGE] ╻ ╻┏━┓┏┳┓┏┳┓╺┳┓
# [MESSAGE] ┃ ┃┣━┫┃┃┃┃┃┃ ┃┃ Version: 2.5
# [MESSAGE] ┗━┛╹ ╹╹ ╹╹ ╹╺┻┛
# [MESSAGE] Compiled at: May 30 2025 09:48:24
# [MESSAGE] Compiled in double precision mode
# [MESSAGE] Computation started at Tue Jul  8 10:40:59 2025
#
# [MESSAGE] [System] CUDA initialized
# [MESSAGE] [System] Using device: NVIDIA GeForce RTX 3080 with id: 0
# [MESSAGE] [System] Compute capability of the device: 8.6
# [MESSAGE] ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━
# [MESSAGE] [ExtendedSystem] (system) Name: Icosphere
# [MESSAGE] [ExtendedSystem] (system) Seed: 1751964059169946634
# [MESSAGE] [GlobalDataBase] Fundamental not specified, using default fundamental, "Time"
# [WARNING] [Time] No timeStep specified, using 0.0 as default.
# ...
