# %%
from particles_mod.HalfPipe import *
import hydrodynamic_int.hessian as hess
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(precision=3)

# %%
def graph_positions(positions : list, title : str =None):
    """
    Graph the positions of particles in a 3D space.
    :param positions: A list of tuples containing the x, y and z coordinates of each particle.
    :param title: The title of the graph.
    """
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    x = [pos[0] for pos in positions]
    y = [pos[1] for pos in positions]
    z = [pos[2] for pos in positions]
    ax.scatter(x, y, z)
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('Z Label')
    if title:
        plt.title(title)
    plt.show()

def plot_eigenvalues(eigenvalues: np.ndarray, title : str =None):
    """
    Plot the eigenvalues of the Hessian matrix.
    :param eigenvalues: A numpy array containing the eigenvalues of the Hessian matrix.
    :param title: The title of the graph.
    """
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(range(len(eigenvalues)), eigenvalues, c='b', marker='o', alpha=0.5)
    ax.set_xlabel('Eigenvalue Index')
    ax.set_ylabel('Eigenvalue')
    if title:
        plt.title(title)
    plt.show()

def createfrontviewsp(ax, positions : list, eigenmode: np.ndarray):
    """
    Create a front view of the eigenmode positions of particles in a 3D space. Thus imply to grpah only the x and z coordinates.
    :param ax: The axis to plot on.
    :param positions: A list of tuples containing the x, y and z coordinates of each particle.
    :param eigenmode: A numpy array containing the eigenmode data in (nparticles, 3) format.
    """
    x = [pos[0] for pos in positions]
    z = [pos[2] for pos in positions]
    x_eigen = [pos[0] + eigenmode[i][0] for i, pos in enumerate(positions)]
    z_eigen = [pos[2] + eigenmode[i][2] for i, pos in enumerate(positions)]
    ax.scatter(x, z, c='b', marker='o', alpha=0.25, label='Original')
    ax.scatter(x_eigen, z_eigen, c='m', marker='o', alpha=0.75, label='Eigenmode')
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_title('Front View')
    ax.legend()

def createsideviewsp(ax, positions : list, eigenmode: np.ndarray):
    """
    Create a side view of the eigenmode positions of particles in a 3D space. Thus imply to grpah only the y and z coordinates.
    :param ax: The axis to plot on.
    :param positions: A list of tuples containing the x, y and z coordinates of each particle.
    :param eigenmode: A numpy array containing the eigenmode data in (nparticles, 3) format.
    """
    y = [pos[1] for pos in positions]
    z = [pos[2] for pos in positions]
    y_eigen = [pos[1] + eigenmode[i][1] for i, pos in enumerate(positions)]
    z_eigen = [pos[2] + eigenmode[i][2] for i, pos in enumerate(positions)]
    ax.scatter(y, z, c='b', marker='o', alpha=0.25, label='Original')
    ax.scatter(y_eigen, z_eigen, c='m', marker='o', alpha=0.75, label='Eigenmode')
    ax.set_xlabel('Y Label')
    ax.set_ylabel('Z Label')
    ax.set_title('Side View')

def createtopviewsp(ax, positions : list, eigenmode: np.ndarray):
    """
    Create a top view of the eigenmode positions of particles in a 3D space. Thus imply to grpah only the x and y coordinates.
    :param ax: The axis to plot on.
    :param positions: A list of tuples containing the x, y and z coordinates of each particle.
    :param eigenmode: A numpy array containing the eigenmode data in (nparticles, 3) format.
    """
    x = [pos[0] for pos in positions]
    y = [pos[1] for pos in positions]
    x_eigen = [pos[0] + eigenmode[i][0] for i, pos in enumerate(positions)]
    y_eigen = [pos[1] + eigenmode[i][1] for i, pos in enumerate(positions)]
    ax.scatter(x, y, c='b', marker='o', alpha=0.25, label='Original')
    ax.scatter(x_eigen, y_eigen, c='m', marker='o', alpha=0.75, label='Eigenmode')
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_title('Top View')

def create3dviewsp(ax, positions : list, eigenmode: np.ndarray):
    """
    Create a 3D view of the eigenmode positions of particles in a 3D space.
    :param ax: The axis to plot on.
    :param positions: A list of tuples containing the x, y and z coordinates of each particle.
    :param eigenmode: A numpy array containing the eigenmode data in (nparticles, 3) format.
    """
    x = [pos[0] for pos in positions]
    y = [pos[1] for pos in positions]
    z = [pos[2] for pos in positions]
    x_eigen = [pos[0] + eigenmode[i][0] for i, pos in enumerate(positions)]
    y_eigen = [pos[1] + eigenmode[i][1] for i, pos in enumerate(positions)]
    z_eigen = [pos[2] + eigenmode[i][2] for i, pos in enumerate(positions)]
    ax.scatter(x, y, z, c='b', marker='o', alpha=0.25, label='Original')
    ax.scatter(x_eigen, y_eigen, z_eigen, c='m', marker='o', alpha=0.75, label='Eigenmode')
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('Z Label')
    ax.set_title('3D View')



def graph_mode (positions : list, eigenmode: np.ndarray, title : str =None):
    """
    Graph the eigenmode positions of particles in a 3D space.
    :param positions: A list of tuples containing the x, y and z coordinates of each particle.
    :param eigenmode: A numpy array containing the eigenmode data in (nparticles, 3) format.
    :param title: The title of the graph.
    """
    fig = plt.figure()
    ax = fig.add_subplot(2, 2, 1)
    createfrontviewsp(ax, positions, eigenmode)
    ax = fig.add_subplot(2, 2, 2)
    createsideviewsp(ax, positions, eigenmode)
    ax = fig.add_subplot(2, 2, 3)
    createtopviewsp(ax, positions, eigenmode)
    ax = fig.add_subplot(2, 2, 4, projection='3d')
    create3dviewsp(ax, positions, eigenmode)
    if title:
        plt.title(title)
    plt.show()

# %%
positions, bonds = construct_structure(length=3, radius=1.5, amplitude=np.pi/2, density=1.0)
print("Pairbonds:")
for i in range(len(bonds['pairbonds']['data'])):
    print(f"Pairbond {i}: {bonds['pairbonds']['data'][i]}")
print("Angular Bonds:")
for i in range(len(bonds['anglebonds']['data'])):
    print(f"Anglebond {i}: {bonds['anglebonds']['data'][i]}")
# Out:
# Pairbonds:
# Pairbond 0: [0, 1, 1.0, np.float64(3.0)]
# Pairbond 1: [2, 3, 1.0, np.float64(3.0)]
# Pairbond 2: [4, 5, 1.0, np.float64(3.0)]
# Pairbond 3: [6, 7, 1.0, np.float64(3.0)]
# Pairbond 4: [0, 2, 1.0, np.float64(1.4999999999999998)]
# Pairbond 5: [1, 3, 1.0, np.float64(1.4999999999999998)]
# Pairbond 6: [2, 4, 1.0, np.float64(1.4999999999999998)]
# Pairbond 7: [3, 5, 1.0, np.float64(1.4999999999999998)]
# Pairbond 8: [4, 6, 1.0, np.float64(1.5)]
# Pairbond 9: [5, 7, 1.0, np.float64(1.5)]
# Pairbond 10: [0, 3, 1.0, np.float64(3.3541019662496843)]
# Pairbond 11: [1, 2, 1.0, np.float64(3.3541019662496843)]
# Pairbond 12: [2, 5, 1.0, np.float64(3.3541019662496847)]
# Pairbond 13: [3, 4, 1.0, np.float64(3.3541019662496847)]
# Pairbond 14: [4, 7, 1.0, np.float64(3.3541019662496847)]
# Pairbond 15: [5, 6, 1.0, np.float64(3.3541019662496847)]
# Angular Bonds:
# Anglebond 0: [0, 2, 4, 1.0, np.float64(0.7853981633974483)]
# Anglebond 1: [1, 3, 5, 1.0, np.float64(0.7853981633974483)]
# Anglebond 2: [2, 4, 6, 1.0, np.float64(2.418858405776378)]
# Anglebond 3: [3, 5, 7, 1.0, np.float64(0.7853981633974483)]
# Hessian matrix:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
# [WARNING] UAMMD-structured Python wrapper is not compatible with UAMMD-structured self restarting mechanism
# [MESSAGE] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# [MESSAGE] ╻ ╻┏━┓┏┳┓┏┳┓╺┳┓
# [MESSAGE] ┃ ┃┣━┫┃┃┃┃┃┃ ┃┃ Version: 2.5
# [MESSAGE] ┗━┛╹ ╹╹ ╹╹ ╹╺┻┛
# [MESSAGE] Compiled at: May 16 2025 14:06:38
# [MESSAGE] Compiled in double precision mode
# [MESSAGE] Computation started at Tue May 20 15:34:02 2025
#
# [MESSAGE] [System] CUDA initialized
# [MESSAGE] [System] Using device: NVIDIA GeForce RTX 3080 with id: 0
# [MESSAGE] [System] Compute capability of the device: 8.6
# [MESSAGE] ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━
# [MESSAGE] [ExtendedSystem] (system) Name: Hessian_Calculation
# [MESSAGE] [ExtendedSystem] (system) Seed: 1747748042806250465
# [MESSAGE] [GlobalDataBase] Fundamental not specified, using default fundamental, "Time"
# [WARNING] [Time] No timeStep specified, using 0.0 as default.
# [MESSAGE] [Basic] Loaded type A, mass: 1.000000, radius: 0.500000, charge: 0.000000
# [MESSAGE] [ParticleData] Created with 12 particles.
# [MESSAGE] [StateLoader] Loading property "id".
# [MESSAGE] [StateLoader] Loading property "position".
# [MESSAGE] [Topology] Loading types into particle data.
# [MESSAGE] [ParticleGroup] Group All created with All selector
# [MESSAGE] [ParticleGroup] Group All contains 12 particles.
# [MESSAGE] [GroupsListFromInputEntries] Added group "All" with 12 particles.
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [Interactor] BondsInteractor: "anglebonds" created.
# [MESSAGE] [Interactor] Acting on group All
# [MESSAGE] [BondsInteractor] (anglebonds) Particles in the bond: id_i----id_j----id_k
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [Interactor] BondsInteractor: "pairbonds" created.
# [MESSAGE] [Interactor] Acting on group All
# [MESSAGE] [BondsInteractor] (pairbonds) Particles in the bond: id_i----id_j
# [MESSAGE] [Topology] Added interactor "anglebonds".
# [MESSAGE] [Topology] Added interactor "pairbonds".
# [MESSAGE] [Interactor] Scheduled created.
# [MESSAGE] [Interactor] Acting on group All
# [MESSAGE] [ParticleGroup] Group All created with All selector
# [MESSAGE] [ParticleGroup] Group All contains 12 particles.
# [MESSAGE] [GroupsListFromInputEntries] Added group "All" with 12 particles.
# [MESSAGE] [IntegratorManager] (integrator) Integrator 'bbk' will run for 1 steps with order 1.
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [Integrator] bbk created.
# [MESSAGE] [Integrator] Acting on group All
# [MESSAGE] [ExtendedSystem] (system) Creating cuda stream
# [MESSAGE] [IntegratorBase] (bbk) Time step: 0.000000
# [MESSAGE] [IntegratorBase] (bbk) Current step: 0
# [MESSAGE] [IntegratorBaseNVT] (bbk) Temperature: 0.000000
# [MESSAGE] [IntegratorBaseNVT] (bbk) kBT (kB 1.000000): 0.000000
# [MESSAGE] [BBK] Created BBK integrator "bbk"
# [MESSAGE] [BBK] (bbk) frictionConstant : 1.000000
# [MESSAGE] [IntegratorUtils] Loading friction constant (1.000000) to all particles.
# [MESSAGE] [BBK] (bbk) stopTransRotSteps : 0
# [MESSAGE] [BBK] (bbk) resetVelocities : 1
# [MESSAGE] [IntegratorManager] (integrator) Integrator 'bbk' loaded.
# [MESSAGE] [ParticleGroup] Group All created with All selector
# [MESSAGE] [ParticleGroup] Group All contains 12 particles.
# [MESSAGE] [GroupsListFromInputEntries] Added group "All" with 12 particles.
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [SimulationStep] (hessianMeasure) intervalStep: 1
# [MESSAGE] [ParticleGroupFromGroupsList] No group name specified, using "All".
# [MESSAGE] [ParticleGroupFromGroupsList] Using group "All".
# [MESSAGE] [SimulationStep] (info) intervalStep: 1
# [MESSAGE] [SimulationStepManager] (simulationStep) Simulation step 'hessianMeasure' loaded.
# [MESSAGE] [SimulationStepManager] (simulationStep) Simulation step 'info' loaded.
# [MESSAGE] [Simulation] Running simulation...
# [MESSAGE] [Simulation] Running integrator (bbk), 1 steps...
# [MESSAGE] [bbk] Adding Interactor Scheduled...
# [MESSAGE] [bbk] Adding updatable
# [MESSAGE] [InfoStep] (info) Total steps: 1
# [MESSAGE] [BBK] Performing initialization step
# [WARNING] [GenerateVelocity] Velocity overwritten!
# [MESSAGE] [Simulation] Mean FPS: 333.183171
# [MESSAGE] ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━ ━
# [MESSAGE] [ExtendedSystem] (system) Destroying cuda stream
# [MESSAGE] Computation finished at Tue May 20 15:34:02 2025
#
# [MESSAGE] Time elapsed since creation: 0.057744s
# [MESSAGE] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛

# %%
hessian = hess.obtainHessian(positions, bonds)
print("Hessian matrix:")
print(hessian[-1,-1,:,:])

# %%
print("Hessian shape: ", hessian.shape)
print("Number of particles: ", len(positions))
# Out:
# Hessian shape:  (12, 12, 3, 3)
# Number of particles:  12

# %%
graph_positions(positions, title="Particle Positions")

# %%
eigenvalues, eigenvectors, hessian_reshaped, eigenvectors_reshaped = hess.diagonalize_hessian(hessian)
print("Number of eigenvalues: ", len(eigenvalues))
print("Eigenvectors shape: ", eigenvectors.shape)
# Out:
# Number of eigenvalues:  36
# Eigenvectors shape:  (36, 12, 3)

# %%
# Check if the eigenvectors are orthogonal
orthogonal = np.allclose(np.dot(eigenvectors_reshaped.T, eigenvectors_reshaped), np.eye(eigenvectors_reshaped.shape[1]))

# %%
plot_eigenvalues(eigenvalues, title="Eigenvalues of Hessian")

# %%
graph_mode(positions, eigenvectors[5,:,:], title="Eigenvectors of the Hessian")
